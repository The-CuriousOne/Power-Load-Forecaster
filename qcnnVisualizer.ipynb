# %%
import torch
import matplotlib.pyplot as plt

# Load the .pth file
checkpoint = torch.load("models\qcnn_model.pth")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\q'
# <>:5: SyntaxWarning: invalid escape sequence '\q'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_23072\3566858704.py:5: SyntaxWarning: invalid escape sequence '\q'
#   checkpoint = torch.load("models\qcnn_model.pth")
# ...

# %%
# Extract training and validation history from logs
train_loss = checkpoint['train_losses']
train_acc = checkpoint['train_accuracies']
val_loss = checkpoint['val_losses']
val_acc = checkpoint['val_accuracies']

# %%
# Verify the contents
print("Training Loss:", train_loss)
print("Training Accuracy:", train_acc)
print("Validation Loss:", val_loss)
print("Validation Accuracy:", val_acc)
print("Number of epochs:", len(train_loss))
# Out:
# Training Loss: [0.008832881310918262, 0.003347938344237119, 0.002807968041878995, 0.0025850736627608993, 0.002453511380892541, 0.002301266304400326, 0.002059259650643825, 0.0019391761179980026, 0.0018715921610610795, 0.0017676994579721539, 0.001704873104199993, 0.0016378758009523153, 0.0016916817726690026, 0.0016171232352262142, 0.0015300253250288887, 0.0015074266755611622, 0.001411894126393015, 0.0013643376766904372, 0.0014510485970486815, 0.0012975824400560986, 0.0013532217975928676, 0.0012662161200145208, 0.0012635007566900503, 0.001246993465133854, 0.0013311603089862514, 0.0012472824440483427, 0.0011936243253303485, 0.0011780701542829894, 0.0011703975679218707, 0.001166575887823912, 0.0011434587241712633, 0.0010787167301912388, 0.0011422783789781046, 0.0011744820767062847, 0.0011347279955599289, 0.0011572931285328601, 0.0011122147691927271, 0.0010849765334654759, 0.0011369017303576438, 0.001145507401839564, 0.001021360141303174, 0.0010700532603044198, 0.0010562685007976813, 0.001
# ...

# %%
# Extract the number of epochs
epochs = range(1, len(train_loss) + 1)

# %%
# Plot Training Loss over Epochs
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_loss, label="Training Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training Accuracy over Epochs
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_acc, label="Training Accuracy", color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Validation Loss over Epochs
plt.figure(figsize=(10, 5))
plt.plot(epochs, val_loss, label="Validation Loss", color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Validation Accuracy over Epochs
plt.figure(figsize=(10, 5))
plt.plot(epochs, val_acc, label="Validation Accuracy", color='green')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Accuracy vs Epochs (combined plot)
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_acc, label="Training Accuracy", color='orange')
plt.plot(epochs, val_acc, label="Validation Accuracy", color='green')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Model Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()
